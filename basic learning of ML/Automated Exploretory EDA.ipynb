# %%
import ydata_profiling

# %%
from ydata_profiling import ProfileReport

# %%
import seaborn as sns

# %%
import pandas as pa
df_train=pa.read_csv('train.csv')
df_train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df=sns.load_dataset('tips')

# %%
profile=ProfileReport(df,explorative=True,dark_mode=True)

# %%
profile.to_file('output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_1=sns.load_dataset('titanic')
df_1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
profile=ProfileReport(df_1,explorative=True,dark_mode=True)

# %%
profile.to_file('df_1.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import pandas as pd
import dtale
dtale.show(df_1)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://SHAON:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV=AutoViz_Class()
# Out:
# Imported v0.1.803. After importing autoviz, you must run '%matplotlib inline' to display charts inline.
#     AV = AutoViz_Class()
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
filename = "titanic.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
#     pandas ascii encoder does not work for this file. Continuing...
#     pandas utf-8 encoder does not work for this file. Continuing...
#     pandas iso-8859-1 encoder does not work for this file. Continuing...
#     pandas cp1252 encoder does not work for this file. Continuing...
#     pandas latin1 encoder does not work for this file. Continuing...
# Not able to read or load file. Please check your inputs and try again...

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# []

# %%
df=sns.load_dataset('titanic')
df.head(5)
# Out:
#    survived  pclass   sex     age  sibsp  parch   fare   embarked class   \
# 0      0        3      male  22.0    1      0     7.2500     S     Third
# 1      1        1    female  38.0    1      0    71.2833     C     First
# 2      1        3    female  26.0    0      0     7.9250     S     Third
# 3      1        1    female  35.0    1      0    53.1000     S     First
# 4      0        3      male  35.0    0      0     8.0500     S     Third
#
#    who    adult_male deck embark_town  alive  alone
# 0    man      True    NaN  Southampton    no  False
# 1  woman     False      C    Cherbourg   yes  False
# 2  woman     False    NaN  Southampton   yes   True
# 3  woman     False      C  Southampton   yes  False
# 4    man      True    NaN  Southampton    no   True

# %%
# !pip install pandas_visual_analysis

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
df.describe()
# Out:
#         survived     pclass        age        sibsp       parch       fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Assuming df is your DataFrame
plt.scatter(df['sepal_length'], df['petal_width'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Width')
plt.title('Scatter Plot of Sepal Length vs Petal Width')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\New folder\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File D:\New folder\anaconda\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\New folder\anaconda\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal_length'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
VisualAnalysis(df)
