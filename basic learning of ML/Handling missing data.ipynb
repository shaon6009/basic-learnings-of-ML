# %%
import pandas as pa
sha=pa.read_csv("E:\csv_or excel_for_python\csv_1.1.csv")
sha
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                  NaN
# 1         NaN                     Level 1                99999
# 2      2021.0                         NaN                  NaN
# 3         NaN                     Level 1                99999
# 4      2021.0                     Level 1                  NaN
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
sha.shape #shape rows and colums
# Out:
# (41715, 10)

# %%
sha.isnull() #if it gives true it means there is a null value, false for opposite
# Out:
#         Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      False                        False                  True
# 1       True                        False                 False
# 2      False                         True                  True
# 3       True                        False                 False
# 4      False                        False                  True
# ...      ...                          ...                   ...
# 41710  False                        False                 False
# 41711  False                        False                 False
# 41712  False                        False                 False
# 41713  False                        False                 False
# 41714  False                        False                 False
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                     False   True          False          False
# ...

# %%
sha.isnull().sum() #how many null value total have in every colum
# Out:
# Year                           14
# Industry_aggregation_NZSIOC    12
# Industry_code_NZSIOC           11
# Industry_name_NZSIOC            7
# Units                           8
# Variable_code                   7
# Variable_name                  10
# Variable_category               4
# Value                           7
# Industry_code_ANZSIC06          7
# dtype: int64

# %%
sha.isnull().sum().sum() #in total null value
# Out:
# 87

# %% [markdown]
# # filling the null vaues

# %%
sha1=pa.read_csv("E:\csv_or excel_for_python\csv_1.1.csv")
sha1.fillna(value=0) #it means o will replace all my null values
sha1
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                  NaN
# 1         NaN                     Level 1                99999
# 2      2021.0                         NaN                  NaN
# 3         NaN                     Level 1                99999
# 4      2021.0                     Level 1                  NaN
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %% [markdown]
# # droping null values

# %%
sha1.dropna()
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 11     2021.0                     Level 1                99999
# 17     2021.0                     Level 1                99999
# 18     2021.0                     Level 1                99999
# 23     2021.0                     Level 1                99999
# 25     2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 11                 All industries  Dollars (millions)           H19
# 17                 All industries  Dollars (millions)           H25
# ...

# %%
sha1.dropna(axis=0)
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 11     2021.0                     Level 1                99999
# 17     2021.0                     Level 1                99999
# 18     2021.0                     Level 1                99999
# 23     2021.0                     Level 1                99999
# 25     2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 11                 All industries  Dollars (millions)           H19
# 17                 All industries  Dollars (millions)           H25
# ...

# %%
sha1.dropna(subset="Units")# fill the null value od=f asingle particular column
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 1         NaN                     Level 1                99999
# 3         NaN                     Level 1                99999
# 5         NaN                     Level 1                  NaN
# 6      2021.0                     Level 1                99999
# 7      2021.0                         NaN                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 1                  All industries  Dollars (millions)           NaN
# 3                  All industries  Dollars (millions)           NaN
# ...

# %%
sha1.dropna(inplace=True) # all none value got repleaced and got a new data set
sha1
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 11     2021.0                     Level 1                99999
# 17     2021.0                     Level 1                99999
# 18     2021.0                     Level 1                99999
# 23     2021.0                     Level 1                99999
# 25     2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 11                 All industries  Dollars (millions)           H19
# 17                 All industries  Dollars (millions)           H25
# ...

# %%
sha1.dropna(thresh=1) #single null value jotogula ase sobgula remove
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 11     2021.0                     Level 1                99999
# 17     2021.0                     Level 1                99999
# 18     2021.0                     Level 1                99999
# 23     2021.0                     Level 1                99999
# 25     2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 11                 All industries  Dollars (millions)           H19
# 17                 All industries  Dollars (millions)           H25
# ...

# %% [markdown]
# # fill value

# %%
sha1=pa.read_csv("E:\csv_or excel_for_python\csv_1.1.csv") #filling null value wuth shaon
sha1.fillna("Shaon")
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                Shaon
# 1       Shaon                     Level 1                99999
# 2      2021.0                       Shaon                Shaon
# 3       Shaon                     Level 1                99999
# 4      2021.0                     Level 1                Shaon
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries               Shaon           H01
# 1                  All industries  Dollars (millions)         Shaon
# ...

# %%
sha1.fillna({"Year":"Rakibul","Industry_code_NZSIOC":"Hasan","Units":"Shaon"})#change every null value column wise
# Out:
#           Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       2021.0                     Level 1                Hasan
# 1      Rakibul                     Level 1                99999
# 2       2021.0                         NaN                Hasan
# 3      Rakibul                     Level 1                99999
# 4       2021.0                     Level 1                Hasan
# ...        ...                         ...                  ...
# 41710   2013.0                     Level 3                 ZZ11
# 41711   2013.0                     Level 3                 ZZ11
# 41712   2013.0                     Level 3                 ZZ11
# 41713   2013.0                     Level 3                 ZZ11
# 41714   2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries               Shaon           H01
# ...

# %%
sha1.fillna(method="ffill") #0 no index er data diye 1 no index er naull value guloke fill up kora
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                  NaN
# 1      2021.0                     Level 1                99999
# 2      2021.0                     Level 1                99999
# 3      2021.0                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           H01
# ...

# %%
sha1.fillna(method="bfill")#backword filling
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                99999
# 1      2021.0                     Level 1                99999
# 2      2021.0                     Level 1                99999
# 3      2021.0                     Level 1                99999
# 4      2021.0                     Level 1                99999
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H05
# ...

# %%
sha1.fillna(method="bfill",axis=1)#axis wise fill korle
# Out:
#           Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0       2021.0                     Level 1       All industries
# 1      Level 1                     Level 1                99999
# 2       2021.0              All industries       All industries
# 3      Level 1                     Level 1                99999
# 4       2021.0                     Level 1                  H08
# ...        ...                         ...                  ...
# 41710   2013.0                     Level 3                 ZZ11
# 41711   2013.0                     Level 3                 ZZ11
# 41712   2013.0                     Level 3                 ZZ11
# 41713   2013.0                     Level 3                 ZZ11
# 41714   2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units          Variable_code  \
# 0                  All industries                 H01                    H01
# ...

# %%
sha1.fillna(4,inplace=True)
sha1
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                    4
# 1         4.0                     Level 1                99999
# 2      2021.0                           4                    4
# 3         4.0                     Level 1                99999
# 4      2021.0                     Level 1                    4
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                   4           H01
# 1                  All industries  Dollars (millions)             4
# ...

# %%
sha.fillna("boom",limit=2)#jotogula row te kompokkhe 2ta null value ase oigula vhange hobe limit onujayi change hoy
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                 boom
# 1        boom                     Level 1                99999
# 2      2021.0                        boom                 boom
# 3        boom                     Level 1                99999
# 4      2021.0                     Level 1                  NaN
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                boom           H01
# 1                  All industries  Dollars (millions)          boom
# ...

# %% [markdown]
# # replace

# %%
sha1=pa.read_csv("E:\csv_or excel_for_python\csv_1.1.csv")
sha1.replace(["Level 1","ZZ11","H08"],"balsal") #only intiger type data will fill
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                      balsal                  NaN
# 1         NaN                      balsal                99999
# 2      2021.0                         NaN                  NaN
# 3         NaN                      balsal                99999
# 4      2021.0                      balsal                  NaN
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3               balsal
# 41711  2013.0                     Level 3               balsal
# 41712  2013.0                     Level 3               balsal
# 41713  2013.0                     Level 3               balsal
# 41714  2013.0                     Level 3               balsal
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %% [markdown]
# # Interpolate

# %%
sha1=pa.read_csv("E:\csv_or excel_for_python\csv_1.1.csv")#the integer type data will fill autometicly
sha1.interpolate()
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                  NaN
# 1      2021.0                     Level 1                99999
# 2      2021.0                         NaN                  NaN
# 3      2021.0                     Level 1                99999
# 4      2021.0                     Level 1                  NaN
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
sha1.interpolate(limit_direction="both",limit=2)
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021.0                     Level 1                  NaN
# 1      2021.0                     Level 1                99999
# 2      2021.0                         NaN                  NaN
# 3      2021.0                     Level 1                99999
# 4      2021.0                     Level 1                  NaN
# ...       ...                         ...                  ...
# 41710  2013.0                     Level 3                 ZZ11
# 41711  2013.0                     Level 3                 ZZ11
# 41712  2013.0                     Level 3                 ZZ11
# 41713  2013.0                     Level 3                 ZZ11
# 41714  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries                 NaN           H01
# 1                  All industries  Dollars (millions)           NaN
# ...
